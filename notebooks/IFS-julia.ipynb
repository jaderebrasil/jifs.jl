# %%
using Distributions
include("../src/ifs.jl")

# %% [markdown]
# ### Exemplo 1 (Sierpinski)

# %%
num_points = 1000
iters = 10000
w, h = (512, 512)

ifs1 = Jifs.sierpinski(w, h)
Jifs.painting!(ifs1, iters, num_points)

# %%
Jifs.showifs(ifs1, iters)
# Out:
# 512×512 Array{RGB{Float64},2} with eltype ColorTypes.RGB{Float64}:
#  RGB{Float64}(1.0,0.666495,1.0)            …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.992011,0.653887,0.990416)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.981385,0.646537,0.97878)      RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.967741,0.637251,0.964139)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,0.707774,1.0)               RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,0.689252,1.0)            …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,0.711082,1.0)               RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,0.682371,1.0)               RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,0.699416,1.0)               RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.959267,0.629686,0.949607)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,0.677089,1.0)            …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,0.655697,0.987879)          RGB{Float64}(0.0,0.0,0.0)
# ...

# %% [markdown]
# ### Exemplo 2 (Fern)

# %%
num_points = 1000
iters = 10000
w, h = (1024, 512)

ifs2 = Jifs.barnsley_fern(w, h)
Jifs.painting!(ifs2, iters, num_points, quad=Jifs.Quad12)

# %%
Jifs.showifs(ifs2, iters)
# Out:
# 512×1024 Array{RGB{Float64},2} with eltype ColorTypes.RGB{Float64}:
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0701123,0.128219,0.106741)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0960735,0.175705,0.146269)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0701085,0.128219,0.106738)
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  ⋮                          ⋱
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
# ...

# %% [markdown]
# ### Exemplo 3 (testing QuadPlot)

# %%
include("../src/ifs.jl")
num_points = 100
iters = 5000
halfmap = Jifs.IFSMap(x -> x ./ 2, color=[1., 0., 0.])
img = Jifs.ImageData(10, 10)

ifs = Jifs.IFS(img, [halfmap], [1])
Jifs.painting!(ifs, iters, num_points, quad=Jifs.Quad0)

# %%
Jifs.showifs(ifs, iters)
# Out:
# 10×10 Array{RGB{Float64},2} with eltype ColorTypes.RGB{Float64}:
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)

# %%
include("../src/ifs.jl")
num_points = 100
iters = 1000
halfmap = Jifs.IFSMap(x -> x ./ 2, color=[1., 0., 0.])
img = Jifs.ImageData(10, 10)
ifs = Jifs.IFS(img, [halfmap], [1])
Jifs.painting!(ifs, iters, num_points, quad=Jifs.Quad1)
# Out:
# WARNING: replacing module Jifs.

# %%
Jifs.showifs(ifs, iters)
# Out:
# 10×10 Array{RGB{Float64},2} with eltype ColorTypes.RGB{Float64}:
#  RGB{Float64}(0.0,0.0,0.0)       …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)          RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)          RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)          RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)          RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.380791,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.457855,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.993703,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)          RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)          RGB{Float64}(0.0,0.0,0.0)

# %%
include("../src/ifs.jl")
num_points = 100
iters = 1000
halfmap = Jifs.IFSMap(x -> x ./ 2, color=[1., 0., 0.])
img = Jifs.ImageData(10, 10)
ifs = Jifs.IFS(img, [halfmap], [1])
Jifs.painting!(ifs, iters, num_points, quad=Jifs.Quad12)

# %%
Jifs.showifs(ifs, iters)

# %% [markdown]
# ### Exemplo 5 (Sierpinski Quad0)

# %%
#==
How can I fix this problem: Test this plot with 250/2500.
After that, test with 1000/10000 as used before.

The colors in the second one are dead. Probably I make something wrong
on scalefactor709. Need to read 
==#
num_points = 250
iters = 2500
w, h = (512, 512)

ifs1 = Jifs.sierpinski(w, h)
Jifs.painting!(ifs1, iters, num_points, quad=Jifs.Quad0)

# %%
Jifs.showifs(ifs1, iters)
# Out:
# 512×512 Array{RGB{Float64},2} with eltype RGB{Float64}:
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
#  ⋮                          ⋱
#  RGB{Float64}(0.0,0.0,0.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)     RGB{Float64}(0.0,0.0,0.0)
# ...
